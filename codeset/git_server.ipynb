# %%
pip install -r requirements.txt

# %%
import pandas as pd

# %%
# try except 내용 추가
try:    
    inDf = pd.read_csv("./dataset/sample.txt")
    inDf
except Exception as e:
    print(e)

# %%
inDf
# Out:
#   regionid   qty
# 0      A01   100

# %%
# load .env 파일 가져오기
